-- %%
CREATE OR REPLACE CONNECTION mysql_gizmobox_db_conn_sql TYPE mysql
OPTIONS (
  host 'database-1.c9sauooguz6t.us-east-2.rds.amazonaws.com', 
  port '3306', 
  user 'admin',
  password 'adminsans'
)

-- %%
CREATE FOREIGN CATALOG IF NOT EXISTS mysql_gizmobox_db_catalog_sql USING CONNECTION mysql_gizmobox_db_conn_sql;

-- %%
SHOW CATALOGS;

-- %%
USE CATALOG mysql_gizmobox_db_catalog_sql;
SHOW SCHEMAS;

-- %%
USE SCHEMA gizmobox;

-- %%
-- See, we are querying the data from the mysql database that is hosted in the amazon rds 
-- Concept of Lakehouse federation - Query Federation and Catalog Federation important
SELECT * FROM refunds;

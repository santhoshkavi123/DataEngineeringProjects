-- %% [markdown]
-- # Extract orders data from the volumes using text format

-- %%
SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/orders`

-- See, we are not able to extract the data in the proper format
-- So, let's try reading the data using 'text' file format

-- %%
SELECT * FROM text.`/Volumes/gizmobox/landing/operational_data/orders`; 

-- Now, we are able to extract the data in the proper format, but still each line is the json object we will proper all the transformations in the silver layer

-- %% [markdown]
-- # Registry the data as View in UC - Bronze layer

-- %%
CREATE OR REPLACE VIEW gizmobox.bronze.v_orders
AS
SELECT * FROM text.`/Volumes/gizmobox/landing/operational_data/orders`;

-- %%
SELECT * FROM gizmobox.bronze.v_orders;

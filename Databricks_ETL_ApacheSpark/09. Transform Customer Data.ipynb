-- %% [markdown]
-- # Transform Customer Data
--
-- 1. Remove records with NULL customer id
-- 2. Remove exact duplicate records
-- 3. Remove duplicate records based on created_timestamp
-- 4. CAST the columns to the correct Data Type
-- 5. Write transformed data to the Silver Schema

-- %% [markdown]
-- ## 1. Remove records with NULL customer id

-- %%
SELECT * FROM gizmobox.bronze.v_customers
WHERE CUSTOMER_ID IS NOT NULL
ORDER BY CUSTOMER_ID;

-- %% [markdown]
-- ## 2. Remove exact duplicate records

-- %%
-- first case is removing the exact duplicate records 
SELECT DISTINCT * FROM gizmobox.bronze.v_customers
WHERE CUSTOMER_ID IS NOT NULL
ORDER BY CUSTOMER_ID;

-- %%
CREATE OR REPLACE TEMPORARY VIEW v_customers_distinct
AS (
  SELECT DISTINCT * FROM gizmobox.bronze.v_customers
  WHERE CUSTOMER_ID IS NOT NULL
  ORDER BY CUSTOMER_ID
);

SELECT * FROM v_customers_distinct;

-- %% [markdown]
-- ## 3. Remove duplicate records based on current timestamp

-- %%
-- Here, we are going to use the window functions to create a row_number

-- %%
CREATE OR REPLACE CONNECTION mysql_gizmobox_db_conn_sql TYPE mysql
OPTIONS (
  host 'database-1.c9sauooguz6t.us-east-2.rds.amazonaws.com', 
  port '3306', 
  user 'admin',
  password 'adminsans'
)

-- %%
CREATE FOREIGN CATALOG IF NOT EXISTS mysql_gizmobox_db_catalog_sql USING CONNECTION mysql_gizmobox_db_conn_sql;

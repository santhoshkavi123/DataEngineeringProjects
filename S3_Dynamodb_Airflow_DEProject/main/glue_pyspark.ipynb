# %%
#!pip3 install pyspark==3.5.5

# %%
import os
os.environ["SPARK_HOME"] = "/Applications/spark"
os.environ["PYSPARK_DRIVER_PYTHON"] = "jupyter"
os.environ["PYSPARK_DRIVER_PYTHON_OPTS"] = "notebook"
os.environ["PYSPARK_PYTHON"] = "python"

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("pyspark-ml") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4") \
    .getOrCreate()

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['AWS_ACCESS_KEY_ID'] = os.environ.get("AWS_ACCESS_KEY_ID")
os.environ['AWS_SECRET_ACCESS_KEY'] = os.environ.get("AWS_SECRET_ACCESS_KEY")
os.environ['AWS_DEFAULT_REGION'] = os.environ.get("AWS_DEFAULT_REGION")


import logging

# Pyspark - related libraries
import pyspark.sql.functions as F
from pyspark.sql.types import (StructType, 
                                StructField,
                                FloatType, 
                                IntegerType, 
                                StringType)
from pyspark.sql.functions import lit
from pyspark.sql import DataFrame
from pyspark.sql.window import Window

# %%
# Test Spark is working or not

data = [
    ("Product A", 5000), 
    ("Product B", 6000), 
    ("Product C", 7000)
]

columns = ["Name", "Price"]
df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +---------+-----+
# |     Name|Price|
# +---------+-----+
# |Product A| 5000|
# |Product B| 6000|
# |Product C| 7000|
# +---------+-----+

# %% [markdown]
# #### 1. Load the Required files

# %%
songs = spark.read.csv("../data/songs.csv", inferSchema = True, header = True)
users = spark.read.csv("../data/users.csv", inferSchema = True, header = True)
streams = spark.read.csv("../data/streams/", inferSchema = True, header = True)


print(f"Shape of the songs dataframe : {songs.count(), len(songs.columns)}")
print(f"Shape of the users dataframe : {users.count(), len(users.columns)}")
print(f"Shape of the streams dataframe : {streams.count(), len(streams.columns)}")
# Out:
# Shape of the songs dataframe : (89741, 21)
# Shape of the users dataframe : (50000, 5)
# Shape of the streams dataframe : (34038, 3)

# %% [markdown]
# #### 2. Check if the columns that we are gonna use having null values or not

# %%
# Extract the date from listen time to use a report_date
streams = (streams.withColumn(
    "report_date", 
    F.to_date(F.col("listen_time"))
))

# Ensure there are no null keys where joins are going to happen
try:
    assert(streams.filter(streams["track_id"].isNotNull()).count() == streams.count())
except Exception as e:
    logging.error(f"==== FAILURE - NO NULL VAUES IN TRACK_ID COLUMN ====")
    raise ValueError(f"==== FAILURE - NO NULL VAUES IN TRACK_ID COLUMN ==== {e}")
else:
    streams = streams.filter(streams["track_id"].isNotNull())
    logging.info(f"==== SUCCESS - CHECK NULL VAUES IN TRACK_ID COLUMN ====") 


# Similarly check if there are any null values for the songs table as well 
try:
    assert(songs.filter(songs["track_id"].isNotNull()).count() == songs.count())
except Exception as e:
    logging.error(f"==== FAILURE - CHECK IF NULL VALUES IN SONGS DATAFRAME ====")
    raise ValueError(f"==== FAILURE - CHECK IF NULL VALUES IN SONGS DATAFRAME ====")
else:
    songs = songs.filter(songs["track_id"].isNotNull())
    logging.info(f"==== SUCCESS - CHECK IF NULL VALUES IN SONGS DATAFRAME")

# %% [markdown]
# #### 3. Calculate KPIs for each songs on a daily basis

# %%
songs_kpi_df = streams.groupBy("track_id", "report_date") \
        .agg(
            F.count("*").alias("total_listens"), 
            F.approx_count_distinct("user_id").alias("unique_users"), 
            F.sum(F.expr("unix_timestamp(listen_time)")).alias("total_listening_time"), 
            F.avg(F.expr("unix_timestamp(listen_time)")).alias("avg_listening_time_per_user")
        )

# Join with songs data to get genre
songs_kpi_with_details_df = songs_kpi_df.join(
    songs, 
    (songs_kpi_df["track_id"] == songs["track_id"]),
    how = "inner"
).drop(songs["track_id"])

songs_kpi_with_details_df.show()
# Out:
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+---+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# |            track_id|report_date|total_listens|unique_users|total_listening_time|avg_listening_time_per_user| id|             artists|          album_name|          track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|track_genre|
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+---+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# |7k9GuJYLp2AzqokyE...| 2024-06-25|            1|           1|          1719334128|              1.719334128E9|  9|      Ross Copperman|              Hunger|              Hunger|        56|     205594|   False|       0.442| 0.632|  1|   -6.77|   1|     0.0295|       0.426|         0.00419|  0.0735|  0.196| 78.899|           4.0|   acoustic|
# |4mzP5mHkRvGxdhdGd...| 2024-06-25|            1|           1|          1719327863|              1.719327863E9| 10|        Zack Tabudlo|             Episode|Give Me Your Forever|        74|     244800|   False|       0.627| 0.363|  8|  -8.127|   1|     0.0291|       0.279|             0.0|  0.0928|  0.301| 99.905|           4.0|   acoustic|
# |0X9MxHR1rTkEHDjp9...| 2024-06-25|            1|           1|          1719361070|               1.71936107E9| 13|       Anna Hamilton|            Bad Liar|            Bad Liar|        62|     248448|   False|       0.691| 0.234|  3|  -6.441|   1|     0.0285|       0.777|             0.0|    0.12|  0.209| 87.103|           4.0|   acoustic|
# |1KHdq8NK9QxnGjdXb...| 2024-06-25|            1|           1|          1719327265|              1.719327265E9| 15|         Landon Pigg|   The Boy Who Never|Falling in Love a...|        58|     244986|   False|       0.489| 0.561|  4|  -7.933|   1|     0.0274|         0.2|         4.56E-5|   0.179|  0.238| 83.457|           3.0|   acoustic|
# |6xKeQgzfjixSUld14...| 2024-06-25|            1|           1|          1719316782|              1.719316782E9| 16|Andrew Foy;Renee Foy|ily (i love you b...|ily (i love you b...|        56|     129750|   False|       0.706| 0.112|  2| -18.098|   1|     0.0391|       0.827|         4.03E-6|   0.125|  0.414|110.154|           4.0|   acoustic|
# |4Yo0igmcoNyat1sec...| 2024-06-25|            1|           1|          1719368912|              1.719368912E9| 17|Andrew Foy;Renee Foy|         At My Worst|         At My Worst|        54|     169728|   False|       0.795|0.0841| 10|  -18.09|   0|     0.0461|       0.742|         1.17E-5|  0.0853|  0.609| 91.803|           4.0|   acoustic|
# |2qLMf6TuEC3ruGJg4...| 2024-06-25|            1|           1|          1719311513|              1.719311513E9| 18|Jason Mraz;Colbie...|We Sing. We Dance...|               Lucky|        68|     189613|   False|       0.625| 0.414|  0|    -8.7|   1|     0.0369|       0.294|             0.0|   0.151|  0.669|130.088|           4.0|   acoustic|
# |6CgNoAbFJ4Q4Id4Ej...| 2024-06-25|            1|           1|          1719334920|               1.71933492E9| 19|Boyce Avenue;Bea ...|Cover Sessions, V...|          Photograph|        67|     260186|   False|       0.717|  0.32|  3|  -8.393|   1|     0.0283|        0.83|             0.0|   0.107|  0.322|107.946|           4.0|   acoustic|
# |2gRKq9rIC5i1zuxp0...| 2024-06-25|            1|           1|          1719312068|              1.719312068E9| 59|    Chord Overstreet|  What's Left of You|  What's Left of You|        57|     178600|    True|       0.731| 0.507|  0|  -6.477|   1|      0.046|       0.572|             0.0|  0.0912|  0.265|117.969|           4.0|   acoustic|
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+---+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# only showing top 20 rows

# %% [markdown]
# #### 4. Compute Window functions

# %%
# Rank Songs within each genre by total_listens
windowSpec = Window.partitionBy("report_date", "track_genre").orderBy(F.desc("total_listens"))
ranked_songs_df = songs_kpi_with_details_df.withColumn("rank", F.rank().over(windowSpec))

# Now, let's filter out the songs where the rank is less than 3
top_songs_per_genre = ranked_songs_df.filter(ranked_songs_df["rank"] <= 3)
top_songs_per_genre.show(5)
# Out:
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+-----+--------------------+--------------------+--------------------+-----------+--------------------+--------+------------+-------+----------+--------+-------+-----------+------------+----------------+--------+-------+------+--------------+-----------+----+
# |            track_id|report_date|total_listens|unique_users|total_listening_time|avg_listening_time_per_user|   id|             artists|          album_name|          track_name| popularity|         duration_ms|explicit|danceability| energy|       key|loudness|   mode|speechiness|acousticness|instrumentalness|liveness|valence| tempo|time_signature|track_genre|rank|
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+-----+--------------------+--------------------+--------------------+-----------+--------------------+--------+------------+-------+----------+--------+-------+-----------+------------+----------------+--------+-------+------+--------------+-----------+----+
# |5Htiwvreftu63Vjsw...| 2024-06-25|            2|           2|          3438633043|             1.7193165215E9|76299|Giuseppe Verdi;Ri...|         Verdi: Aida|"Verdi: Aida, Act...|     Ramfis|                Aida| Radamès|     Amneris| Coro)"|        26|  187866|  False|      0.376|       0.404|             9.0| -11.763|      1|0.0716|         0.979|      0.159|   1|
# |54yvP5Iqo4sxdoXUe...| 2024-06-25|            2|           2|          3438635118|              1.719317559E9|76349|Giuseppe Verdi;Ri...|         Verdi: Aida|"Verdi: Aida, Act...|  o diletta| appressati"" (Am...|    Aida|   Radamès)"|     25|    165440|   False|  0.353|      0.213|           4|         -15.988|       0| 0.0428| 0.982|       1.61E-4|       0.34|   1|
# |2AczNQ6f0bqfBU3oE...| 2024-06-25|            1|           1|          1719332709|              1.719332709E9|76298|Giuseppe Verdi;Ri...|         Verdi: Aida|"Verdi: Aida, Act...| Messaggero|             Radamès|  Ramfis|        Coro|   Aida| Amneris)"|      25| 204093|      False|       0.347|           0.265|       0|-16.853|   1.0|        0.0893|      0.983|   1|
# |23ScWxX03wsFf1oyi...| 2024-06-25|            2|           2|          3438707130|              1.719353565E9|75549|     Hayley Westenra|Pure (Includes Bo...|"River Of Dreams ...| RV 297"")"|                  24|  259760|       False|  0.233|     0.177|       7|-14.373|          1|      0.0379|           0.849|7.26e-06|  0.182| 0.132|       119.938|          1|   1|
# |3NgDjqxOAEpwN98ng...| 2024-06-25|            1|           1|          1719337824|              1.719337824E9|76848|Giuseppe Verdi;Ri...|         Verdi: Aida|"Verdi: Aida, Act...|     Aida)"|                  21|  115293|       False|  0.255|     0.166|       5|-18.352|          0|        0.05|           0.983|1.82e-05|  0.647| 0.112|        83.306|          1|   2|
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+-----+--------------------+--------------------+--------------------+-----------+--------------------+--------+------------+-------+----------+--------+-------+-----------+------------+----------------+--------+-------+------+--------------+-----------+----+
# only showing top 5 rows

# %%
# Find out the top 5 genres based on total listeners across all songs and all days
genre_window = Window.partitionBy("report_date").orderBy(F.desc("total_listens"))
top_genres = top_songs_per_genre.withColumn("genre_rank", F.rank().over(genre_window)).filter(F.col("genre_rank") <= 5)
top_genres.show(5)
# Out:
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+------+--------------------+-----------------------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+----+----------+
# |            track_id|report_date|total_listens|unique_users|total_listening_time|avg_listening_time_per_user|    id|             artists|                         album_name|          track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|track_genre|rank|genre_rank|
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+------+--------------------+-----------------------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+----+----------+
# |0BtD9k8XjGliQJMS2...| 2024-06-25|            5|           5|          8596706764|             1.7193413528E9| 77893|  Filipe Escandurras|               Escandurras In Sa...|      Varias Queixas|        42|     275541|   False|       0.406| 0.719|  4|  -6.194|   0|     0.0825|       0.581|             0.0|   0.396|  0.584|  88.63|           4.0|     pagode|   1|         1|
# |3u2jm2FZ4x5p8k3Xy...| 2024-06-25|            5|           5|          8596712116|             1.7193424232E9|103047|     Michael Jackson|                    Weihnachtssongs|Little Christmas ...|         0|     216946|   False|       0.468| 0.457|  5|  -6.386|   1|     0.0241|       0.698|             0.0|   0.142|  0.372| 84.557|           4.0|       soul|   1|         1|
# |4gDajIG4yNgBtym4z...| 2024-06-25|            4|           4|          6877285438|             1.7193213595E9|  5254|        桶狭間ありさ|TVアニメ『呪術廻戦』オリジナル・...|          自閉円頓裹|        42|     112533|   False|        0.51| 0.942|  2|  -7.227|   1|     0.0368|     0.00544|           0.707|  0.0649|  0.514|159.922|           4.0|      anime|   1|         3|
# |2KvhjbZPPtNXTB6wi...| 2024-06-25|            4|           4|          6877374661|            1.71934366525E9|  5543|              Maretu|                   Coin locker Baby|          Mind brand|        61|     259230|    True|        0.51| 0.963| 10|  -2.662|   0|     0.0523|     0.00806|         1.51E-4|   0.175|   0.57|155.976|           4.0|      anime|   1|         3|
# |6zeIPnFq1B3H9XoNA...| 2024-06-25|            4|           4|          6877332319|            1.71933307975E9|  7467|The Kentucky Colo...|                  Long Journey Home|   Long Journey Home|        23|     117957|   False|       0.476| 0.624|  9| -11.545|   1|      0.182|       0.867|         0.00139|   0.872|  0.678| 76.699|           4.0|  bluegrass|   1|         3|
# +--------------------+-----------+-------------+------------+--------------------+---------------------------+------+--------------------+-----------------------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+----+----------+
# only showing top 5 rows

# %%
final_df = top_genres.select(
    F.col("report_date"),
    F.col("track_id"), 
    F.col("track_name"), 
    F.col("artists"), 
    F.col("track_genre"), 
    F.col("total_listens"), 
    F.col("unique_users"), 
    F.col("total_listening_time"), 
    F.col("avg_listening_time_per_user")
)

# %%
final_df.show()
# Out:
# +-----------+--------------------+--------------------+--------------------+-------------+-------------+------------+--------------------+---------------------------+
# |report_date|            track_id|          track_name|             artists|  track_genre|total_listens|unique_users|total_listening_time|avg_listening_time_per_user|
